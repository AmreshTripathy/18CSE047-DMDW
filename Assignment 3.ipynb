# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "E:/taxi_data.csv"

# %%
import pandas as pd
data = pd.read_csv(path)

# %%
data
# Out:
#           LON       LAT                          NAME
# 0    28.17858 -25.73882         11th Street Taxi Rank
# 1    28.17660 -25.73795    81 Bazaar Street Taxi Rank
# 2    27.83239 -26.53722          Adams Road Taxi Rank
# 3    28.12514 -26.26666  Alberton City Mall Taxi Rank
# 4    28.10144 -26.10567      Alexandra Main Taxi Rank
# ..        ...       ...                           ...
# 833  27.82999 -26.24445         Zola Clinic Taxi Rank
# 834  27.83991 -26.24235                Zola Taxi Rank
# 835  27.86166 -26.23624               Zondi Taxi Rank
# 836  28.39097 -26.30931            kwaThema Taxi Rank
# 837       NaN       NaN                           NaN
#
# [838 rows x 3 columns]

# %%
data.head()
# Out:
#         LON       LAT                          NAME
# 0  28.17858 -25.73882         11th Street Taxi Rank
# 1  28.17660 -25.73795    81 Bazaar Street Taxi Rank
# 2  27.83239 -26.53722          Adams Road Taxi Rank
# 3  28.12514 -26.26666  Alberton City Mall Taxi Rank
# 4  28.10144 -26.10567      Alexandra Main Taxi Rank

# %%
data.tail()
# Out:
#           LON       LAT                   NAME
# 833  27.82999 -26.24445  Zola Clinic Taxi Rank
# 834  27.83991 -26.24235         Zola Taxi Rank
# 835  27.86166 -26.23624        Zondi Taxi Rank
# 836  28.39097 -26.30931     kwaThema Taxi Rank
# 837       NaN       NaN                    NaN

# %%
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (837, 3)

# %%
data.head()
# Out:
#         LON       LAT                          NAME
# 0  28.17858 -25.73882         11th Street Taxi Rank
# 1  28.17660 -25.73795    81 Bazaar Street Taxi Rank
# 2  27.83239 -26.53722          Adams Road Taxi Rank
# 3  28.12514 -26.26666  Alberton City Mall Taxi Rank
# 4  28.10144 -26.10567      Alexandra Main Taxi Rank

# %%
plt.scatter(data['LON'],data['LAT'],c='green')
plt.xlabel('LON')
plt.ylabel('LAT')
plt.show()

# %%
plt.hist(data['LAT'])
plt.show()

# %%
plt.hist(data['LAT'],color='green',edgecolor='white',bins=5)
plt.title("Histogram of LAT")
plt.xlabel("frequencies")
plt.ylabel("LAT")
plt.show()

# %%
import seaborn as snc

# %%
snc.set(style='darkgrid')
snc.regplot(x=data['LON'],y=data['LAT'])

# %%
snc.set(style='darkgrid')
snc.regplot(x=data['LON'],y=data['LAT'],marker='*',fit_reg=False)

# %%
snc.distplot(data['LON'])

# %%
snc.distplot(data['LON'],kde=False)

# %%
snc.distplot(data['LON'],kde=False,bins=5)

# %%
snc.countplot(x="LON",data=data)

# %%
snc.countplot(x="LON",data=data,hue='Automatic')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-0c27b1f4bd60> in <module>
# ----> 1 snc.countplot(x="LON",data=data,hue='Automatic')
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3553                           estimator, ci, n_boot, units, seed,
#    3554                           orient, color, palette, saturation,
# -> 3555                           errcolor, errwidth, capsize, dodge)
#    3556
#    3557     plotter.value_label = "count"
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1613         """Initialize the plotter."""
# ...

# %%
snc.boxplot(y=data['LAT'])

# %%
snc.boxplot(x=data['LON'])
